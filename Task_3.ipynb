# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogesh7920/Pascal-VOC/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing processed data from Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
data_path= "/content/drive/MyDrive/cache/"

# %% [markdown]
# # Importing the necessary libraries

# %%
import os
import numpy as np
import pandas as pd
import cv2
from glob import glob
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Dropout
# from tensorflow.keras.layers.merge import add
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, Flatten,Input, Convolution2D, Dropout, LSTM, TimeDistributed, Embedding, Bidirectional, Activation, RepeatVector,Concatenate
from tensorflow.keras.models import Sequential, Model
from tensorflow.image import resize, ResizeMethod

# %%
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Reading the Images and Descriptions

# %%
get_resized_images = True

if get_resized_images:
    abstract_images = np.load(data_path+'abstract_images_resized.npy', allow_pickle=True)
else:
    abstract_images = np.load(data_path+'abstract_images.npy', allow_pickle=True)
abstract_images = abstract_images[:, :, :, :3]

if get_resized_images:
    pascal_images = np.load(data_path+'pascal_images_resized.npy', allow_pickle=True)
else:
    pascal_images = np.load(data_path+'pascal_images.npy', allow_pickle=True)

abstract_annots = np.load(data_path+'abstract_annots.npy', allow_pickle=True)
pascal_annots = np.load(data_path+'pascal_annots.npy', allow_pickle=True)

# abstract_annots_concat = np.load( 'abstract_annots_concat.npy', allow_pickle=True)
# pascal_annots_concat = np.load('pascal_annots_concat.npy', allow_pickle=True)

# %%
for i in range(len(abstract_annots)):
  abstract_annots[i].pop(0)
  for j in range(len(abstract_annots[i])):
    abstract_annots[i][j]=abstract_annots[i][j].split('\n')[0]

# %%
for i in range(len(pascal_annots)):
  pascal_annots[i].pop(0)
  for j in range(len(pascal_annots[i])):
    pascal_annots[i][j]=pascal_annots[i][j].split('\n')[0]

# %% [markdown]
# #Image Preprocessing

# %%
normalize=True
if normalize and np.max(abstract_images) == 255:
  abstract_images = abstract_images / 255

if normalize and np.max(pascal_images) == 255:
  pascal_images = pascal_images / 255

# %%
input_shape=(224, 224, 3)

def resize_images(dataset):
    ls = []
    for img in tqdm(dataset):
        img = resize(img, size=input_shape[0:2], method=ResizeMethod.AREA)
        ls.append(img)
    return np.array(ls)

if not get_resized_images:
    pascal_images = resize_images(pascal_images)
    abstract_images = resize_images(abstract_images)
    np.save(data_path + 'abstract_images_resized.npy', abstract_images)
    np.save(data_path + 'pascal_images_resized.npy', pascal_images)

# %% [markdown]
# ###Visualising the images along with the caption for abstract datasest

# %%
for i in range(1):
  plt.figure()
  plt.xlabel(abstract_annots[i][1])
  plt.imshow(abstract_images[i]/255)

# %% [markdown]
# # Combining both pascal and abstract datasets

# %%
images = np.concatenate((abstract_images,pascal_images),axis=0)
annots = np.concatenate((abstract_annots,pascal_annots),axis=0)

# %%
# adding a start symbol and an end symbol to each sentence
def preprocess_txt(text):
  txt = '<start> ' + text + ' <end>'
  txt = txt.lower()
  return txt

# %%
for i in range(len(annots)):
  for j in range(len(annots[i])):
    annots[i][j]=preprocess_txt(annots[i][j])

# %% [markdown]
# # Vectorizing the images using pretrained VGG16

# %%
from tensorflow.keras.applications import VGG16

# %%
CNNmodel = VGG16(include_top=False,input_shape=(224,224,3),pooling="avg")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
CNNmodel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
preds=CNNmodel.predict(images)

# %%
image_predict_id=[]
caption_dataset=[]

for i in range(len(preds)):
  n=len(annots[i])
  image_predict_id.extend([i]*n)
  caption_dataset.extend(annots[i])

# %%
print(image_predict_id[1],caption_dataset[1])
# Out:
# 0 <start> jenny and mike are playing baseball together. <end>

# %% [markdown]
# # Tokenizing the captions

# %%
top_k=2000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')

# %%
tokenizer.fit_on_texts(caption_dataset)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
train_seqs = tokenizer.texts_to_sequences(caption_dataset)

# %%
image_id_train, image_id_test, encoded_train, encoded_test = train_test_split(image_predict_id, train_seqs, test_size=0.2, random_state=42)

# %%
del image_predict_id

# %%
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
max_length = calc_max_length(train_seqs)

# %% [markdown]
# # Creating a generator to generate the data for the model

# %%
VOCAB_SIZE = top_k

# %%
def data_generator(descriptions, photo_id, MAX_LENGTH,VOCAB_SIZE, num_photos_per_batch):
    X, y_in, y_out = list(), list(), list()
    n=0
    # loop for ever over images
    while 1:
        for i in range(len(descriptions)):
            n+=1
            # retrieve the photo id 
            photo = photo_id[i]
            for j in range(1,len(descriptions[i])):
                in_seq , op_seq = descriptions[i][:j],descriptions[i][j]
                #converting input sequence to fix length
                in_seq = pad_sequences([in_seq],maxlen=MAX_LENGTH,padding="post")[0]
                # converting op_seq to vocabulary size
                op_seq = to_categorical([op_seq],num_classes=VOCAB_SIZE)[0]
                X.append(preds[photo])
                y_in.append(in_seq)
                y_out.append(op_seq)
            # yield the batch data
            if n==num_photos_per_batch:
                yield [np.array(X), np.array(y_in)], np.array(y_out)
                X, y_in, y_out = list(), list(), list()
                n=0

# %% [markdown]
# # Model

# %%
VOCAB_SIZE = top_k
EMBEDDING_SIZE = 128
max_len = max_length

# this part takes the vectorized image (Output of VGG16) as input
image_descr_model = Sequential()
# input layer
image_descr_model.add(Dense(EMBEDDING_SIZE, input_shape=(512,), activation='relu'))
# Repeating the output of previous layer maximum length of string  number of times.
image_descr_model.add(RepeatVector(max_len))

image_descr_model.summary()


# This part takes the sequence of word upto current timestamp
RNNmodel = Sequential()
# adding an embedding layer
RNNmodel.add(Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_SIZE, input_length=max_len))
# Adding a LSTM layer
RNNmodel.add(LSTM(256, return_sequences=True))
# Applies the dense layer to every timestep
RNNmodel.add(TimeDistributed(Dense(EMBEDDING_SIZE)))

RNNmodel.summary()

# concatenating both the models
concat_model = Concatenate()([image_descr_model.output, RNNmodel.output])
# adding a LSTM layer
x = LSTM(128, return_sequences=True)(concat_model)
# adding a LSTM layer
x = LSTM(512, return_sequences=False)(x)
# adding a ouput layer
x = Dense(VOCAB_SIZE)(x)
out = Activation('softmax')(x)
model = Model(inputs=[image_descr_model.input, RNNmodel.input], outputs = out)

# model.load_weights("/content/drive/MyDrive/datasets/model.h5")
model.compile(loss='categorical_crossentropy', optimizer='RMSprop', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 49, 128)           0
# =================================================================
# Total params: 65,664
# Trainable params: 65,664
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 49, 128)           256000
# _________________________________________________________________
# lstm (LSTM)                  (None, 49, 256)           394240
# _________________________________________________________________
# time_distributed (TimeDistri (None, 49, 128)           32896
# =================================================================
# Total params: 683,136
# Trainable params: 683,136
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# embedding_input (InputLayer)    [(None, 49)]         0
# __________________________________________________________________________________________________
# dense_input (InputLayer)        [(None, 512)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 49, 128)      256000      embedding_input[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          65664       dense_input[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 49, 256)      394240      embedding[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 49, 128)      0           dense[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 49, 128)      32896       lstm[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 49, 256)      0           repeat_vector[0][0]
#                                                                  time_distributed[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 49, 128)      197120      concatenate[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 512)          1312768     lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2000)         1026000     lstm_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 2000)         0           dense_2[0][0]
# ==================================================================================================
# Total params: 3,284,688
# Trainable params: 3,284,688
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
checkpoint_path = "/content/drive/MyDrive/datasets/model.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 verbose=1,save_best_only=True)
es = tf.keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True)

# %% [markdown]
# ### Creating the training and validation generator

# %%
train_generator = data_generator(encoded_train,image_id_train,max_length,VOCAB_SIZE,16)
val_generator = data_generator(encoded_test,image_id_test,max_length,VOCAB_SIZE,2)

# %%
# model.load_weights("/content/drive/MyDrive/datasets/model.h5")

# %% [markdown]
# ### Training Model

# %%
history=model.fit(train_generator,steps_per_epoch=len(image_id_train) // 16,batch_size=16,epochs=50,validation_data=val_generator,validation_steps=len(image_id_test) // 16,callbacks=[cp_callback,es])
# Out:
# Epoch 1/50
# 3820/3820 [==============================] - 189s 48ms/step - loss: 4.6680 - accuracy: 0.1471 - val_loss: 3.8561 - val_accuracy: 0.2726
#
# Epoch 00001: val_loss improved from inf to 3.85606, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 2/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 3.6760 - accuracy: 0.2995 - val_loss: 3.2834 - val_accuracy: 0.3541
#
# Epoch 00002: val_loss improved from 3.85606 to 3.28341, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 3/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 3.2053 - accuracy: 0.3620 - val_loss: 3.0705 - val_accuracy: 0.3910
#
# Epoch 00003: val_loss improved from 3.28341 to 3.07048, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 4/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.9535 - accuracy: 0.4010 - val_loss: 2.8813 - val_accuracy: 0.4228
#
# Epoch 00004: val_loss improved from 3.07048 to 2.88132, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 5/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.8007 - accuracy: 0.4261 - val_loss: 2.7848 - val_accuracy: 0.4405
#
# Epoch 00005: val_loss improved from 2.88132 to 2.78477, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 6/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.6900 - accuracy: 0.4437 - val_loss: 2.6843 - val_accuracy: 0.4580
#
# Epoch 00006: val_loss improved from 2.78477 to 2.68428, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 7/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.6102 - accuracy: 0.4583 - val_loss: 2.6554 - val_accuracy: 0.4682
#
# Epoch 00007: val_loss improved from 2.68428 to 2.65544, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 8/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.5400 - accuracy: 0.4705 - val_loss: 2.6606 - val_accuracy: 0.4700
#
# Epoch 00008: val_loss did not improve from 2.65544
# Epoch 9/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.4880 - accuracy: 0.4782 - val_loss: 2.5514 - val_accuracy: 0.4806
#
# Epoch 00009: val_loss improved from 2.65544 to 2.55136, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 10/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.4439 - accuracy: 0.4853 - val_loss: 2.5603 - val_accuracy: 0.4748
#
# Epoch 00010: val_loss did not improve from 2.55136
# Epoch 11/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.4067 - accuracy: 0.4907 - val_loss: 2.5999 - val_accuracy: 0.4685
#
# Epoch 00011: val_loss did not improve from 2.55136
# Epoch 12/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.3833 - accuracy: 0.4946 - val_loss: 2.5803 - val_accuracy: 0.4813
#
# Epoch 00012: val_loss did not improve from 2.55136
# Epoch 13/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.3501 - accuracy: 0.4983 - val_loss: 2.4923 - val_accuracy: 0.4932
#
# Epoch 00013: val_loss improved from 2.55136 to 2.49231, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 14/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.3274 - accuracy: 0.5014 - val_loss: 2.4552 - val_accuracy: 0.4911
#
# Epoch 00014: val_loss improved from 2.49231 to 2.45523, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 15/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.3191 - accuracy: 0.5026 - val_loss: 2.5098 - val_accuracy: 0.4795
#
# Epoch 00015: val_loss did not improve from 2.45523
# Epoch 16/50
# 3820/3820 [==============================] - 182s 48ms/step - loss: 2.3093 - accuracy: 0.5046 - val_loss: 2.4671 - val_accuracy: 0.4903
#
# Epoch 00016: val_loss did not improve from 2.45523
# Epoch 17/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.2888 - accuracy: 0.5065 - val_loss: 2.5413 - val_accuracy: 0.4706
#
# Epoch 00017: val_loss did not improve from 2.45523
# Epoch 18/50
# 3820/3820 [==============================] - 182s 48ms/step - loss: 2.2790 - accuracy: 0.5088 - val_loss: 2.4783 - val_accuracy: 0.4972
#
# Epoch 00018: val_loss did not improve from 2.45523
# Epoch 19/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.2560 - accuracy: 0.5115 - val_loss: 2.5333 - val_accuracy: 0.4896
#
# Epoch 00019: val_loss did not improve from 2.45523
# Epoch 20/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.2342 - accuracy: 0.5143 - val_loss: 2.5080 - val_accuracy: 0.4917
#
# Epoch 00020: val_loss did not improve from 2.45523
# Epoch 21/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.2224 - accuracy: 0.5158 - val_loss: 2.4926 - val_accuracy: 0.4991
#
# Epoch 00021: val_loss did not improve from 2.45523
# Epoch 22/50
# 3820/3820 [==============================] - 183s 48ms/step - loss: 2.2243 - accuracy: 0.5166 - val_loss: 2.4061 - val_accuracy: 0.5024
#
# Epoch 00022: val_loss improved from 2.45523 to 2.40610, saving model to /content/drive/MyDrive/datasets/model.h5
# Epoch 23/50
# 3820/3820 [==============================] - 179s 47ms/step - loss: 2.2038 - accuracy: 0.5200 - val_loss: 2.4558 - val_accuracy: 0.4981
#
# Epoch 00023: val_loss did not improve from 2.40610
# Epoch 24/50
# 3820/3820 [==============================] - 179s 47ms/step - loss: 2.1876 - accuracy: 0.5219 - val_loss: 2.4770 - val_accuracy: 0.4970
#
# Epoch 00024: val_loss did not improve from 2.40610
# Epoch 25/50
# 3820/3820 [==============================] - 179s 47ms/step - loss: 2.1864 - accuracy: 0.5232 - val_loss: 2.4710 - val_accuracy: 0.4962
#
# Epoch 00025: val_loss did not improve from 2.40610
# Epoch 26/50
# 3820/3820 [==============================] - 180s 47ms/step - loss: 2.1874 - accuracy: 0.5235 - val_loss: 2.4881 - val_accuracy: 0.4947
#
# Epoch 00026: val_loss did not improve from 2.40610
# Epoch 27/50
# 3820/3820 [==============================] - 180s 47ms/step - loss: 2.1899 - accuracy: 0.5236 - val_loss: 2.5595 - val_accuracy: 0.4864
#
# Epoch 00027: val_loss did not improve from 2.40610
# Epoch 28/50
# 3820/3820 [==============================] - 180s 47ms/step - loss: 2.1872 - accuracy: 0.5219 - val_loss: 2.5264 - val_accuracy: 0.4886
#
# Epoch 00028: val_loss did not improve from 2.40610
# Epoch 29/50
# 3820/3820 [==============================] - 180s 47ms/step - loss: 2.1616 - accuracy: 0.5237 - val_loss: 2.5136 - val_accuracy: 0.4955
#
# Epoch 00029: val_loss did not improve from 2.40610
# Epoch 30/50
# 3820/3820 [==============================] - 180s 47ms/step - loss: 2.1506 - accuracy: 0.5250 - val_loss: 2.4351 - val_accuracy: 0.5047
#
# Epoch 00030: val_loss did not improve from 2.40610
# Epoch 31/50
# 3820/3820 [==============================] - 179s 47ms/step - loss: 2.1524 - accuracy: 0.5260 - val_loss: 2.4842 - val_accuracy: 0.5004
#
# Epoch 00031: val_loss did not improve from 2.40610
# Epoch 32/50
# 3820/3820 [==============================] - 180s 47ms/step - loss: 2.1459 - accuracy: 0.5273 - val_loss: 2.5145 - val_accuracy: 0.4985
#
# Epoch 00032: val_loss did not improve from 2.40610

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
epochs = len(history['loss'])
ax[0].plot(range(epochs), history['loss'])
ax[0].plot(range(epochs), history['val_loss'])
ax[1].plot(range(epochs), history['accuracy'])
ax[1].plot(range(epochs), history['val_accuracy'])
ax[0].set_title('Loss')
ax[0].set_xlabel('epochs')
ax[1].set_title('accuracy')
ax[1].set_xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
for i in range(10):
    
    id = np.random.randint(0,1500)
    test_feature = preds[id].reshape(1,512)
    
    
    text_inp = ['<start>']

    count = 0
    caption = ''
    while count < max_length:
        count += 1
        encoded = tokenizer.texts_to_sequences(text_inp)
        encoded = pad_sequences([encoded],maxlen=max_length,padding="post")
        prediction = np.argmax(model.predict([test_feature, encoded]))
        sampled_word = tokenizer.index_word[prediction]
        if sampled_word == '<end>':
            break

        caption = caption + ' ' + sampled_word
        text_inp.append(sampled_word)
    plt.figure(figsize=(8,8))  
    plt.imshow(images[id] /255)
    original_caption=' '.join(annots[id][0].split()[1:-1])
    plt.xlabel('Generated Caption:'+caption+'\nOriginal Caption:'+original_caption)
    plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
